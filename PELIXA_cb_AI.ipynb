# %%
import pandas as pd  # Import pandas library
import numpy as np  # Import numpy library
from imblearn.over_sampling import RandomOverSampler  # Import RandomOverSampler
from sklearn.model_selection import train_test_split  # Import train_test_split
from tensorflow.keras.models import Sequential  # Import Sequential model
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense  # Import necessary layers
from tensorflow.keras.callbacks import ModelCheckpoint  # Import ModelCheckpoint

# Load the dataset
data = pd.read_csv('C:\\Users\\Madhusudan\\PELIXA\\hmnist_28_28_RGB.csv')
x = data.drop('label', axis=1)
y = data['label']

# Oversample the data
oversample = RandomOverSampler(random_state=42)
x_resampled, y_resampled = oversample.fit_resample(x, y)

# Reshape the data
x_resampled = np.array(x_resampled).reshape(-1, 28, 28, 3)

# Normalize the data
mean = np.mean(x_resampled)
std = np.std(x_resampled)
x_resampled = (x_resampled - mean) / std

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(
    x_resampled, y_resampled, test_size=0.2, random_state=1
)

# Define the model architecture
model = Sequential([
    Input(shape=(28, 28, 3)),  # Adjusted input shape to match data
    Conv2D(16, kernel_size=(3, 3), activation='relu', padding='same'),
    Conv2D(32, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2)),
    Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=(2, 2), padding='same'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(7, activation='softmax')  # Adjust the number of classes as needed
])

# Compile the model
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Define the ModelCheckpoint callback
callback = ModelCheckpoint(
    filepath='best_model.keras',  # Save the best model
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# Train the model
history = model.fit(
    X_train, Y_train,
    validation_split=0.2,
    batch_size=128,
    epochs=20,
    callbacks=[callback]
)

# Save the final model
model.save('final_model.h5')
print("Saved 'final_model.h5'")

# Save mean and std for normalization
np.save('mean.npy', mean)
np.save('std.npy', std)
# Out:
# Epoch 1/20
# 235/235 [==============================] - ETA: 0s - loss: 1.2106 - accuracy: 0.5265
# Epoch 1: val_accuracy improved from -inf to 0.68282, saving model to best_model.keras
# 235/235 [==============================] - 21s 78ms/step - loss: 1.2106 - accuracy: 0.5265 - val_loss: 0.8775 - val_accuracy: 0.6828
# Epoch 2/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.7366 - accuracy: 0.7311
# Epoch 2: val_accuracy improved from 0.68282 to 0.77843, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.7360 - accuracy: 0.7313 - val_loss: 0.5941 - val_accuracy: 0.7784
# Epoch 3/20
# 235/235 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.8186
# Epoch 3: val_accuracy improved from 0.77843 to 0.82623, saving model to best_model.keras
# 235/235 [==============================] - 18s 76ms/step - loss: 0.5043 - accuracy: 0.8186 - val_loss: 0.4707 - val_accuracy: 0.8262
# Epoch 4/20
# 235/235 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8769
# Epoch 4: val_accuracy improved from 0.82623 to 0.88948, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.3447 - accuracy: 0.8769 - val_loss: 0.3201 - val_accuracy: 0.8895
# Epoch 5/20
# 235/235 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9129
# Epoch 5: val_accuracy improved from 0.88948 to 0.91092, saving model to best_model.keras
# 235/235 [==============================] - 18s 76ms/step - loss: 0.2493 - accuracy: 0.9129 - val_loss: 0.2597 - val_accuracy: 0.9109
# Epoch 6/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.2084 - accuracy: 0.9267
# Epoch 6: val_accuracy improved from 0.91092 to 0.91465, saving model to best_model.keras
# 235/235 [==============================] - 17s 74ms/step - loss: 0.2083 - accuracy: 0.9268 - val_loss: 0.2332 - val_accuracy: 0.9146
# Epoch 7/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9461
# Epoch 7: val_accuracy improved from 0.91465 to 0.93569, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.1532 - accuracy: 0.9461 - val_loss: 0.1902 - val_accuracy: 0.9357
# Epoch 8/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9756
# Epoch 12: val_accuracy did not improve from 0.96032
# 235/235 [==============================] - 17s 74ms/step - loss: 0.0681 - accuracy: 0.9756 - val_loss: 0.1758 - val_accuracy: 0.9470
# Epoch 13/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0754 - accuracy: 0.9741
# Epoch 13: val_accuracy did not improve from 0.96032
# 235/235 [==============================] - 17s 74ms/step - loss: 0.0755 - accuracy: 0.9741 - val_loss: 0.1707 - val_accuracy: 0.9455
# Epoch 14/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0556 - accuracy: 0.9810
# Epoch 14: val_accuracy did not improve from 0.96032
# 235/235 [==============================] - 18s 76ms/step - loss: 0.0556 - accuracy: 0.9811 - val_loss: 0.1915 - val_accuracy: 0.9473
# Epoch 15/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9869
# Epoch 15: val_accuracy did not improve from 0.96032
# 235/235 [==============================] - 18s 76ms/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.2044 - val_accuracy: 0.9427
# Epoch 16/20
# 235/235 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9760
# Epoch 16: val_accuracy improved from 0.96032 to 0.96658, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0705 - accuracy: 0.9760 - val_loss: 0.1394 - val_accuracy: 0.9666
# Epoch 17/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0263 - accuracy: 0.9914
# Epoch 17: val_accuracy improved from 0.96658 to 0.96698, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0264 - accuracy: 0.9913 - val_loss: 0.1341 - val_accuracy: 0.9670
# Epoch 18/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9921
# Epoch 18: val_accuracy improved from 0.96698 to 0.96924, saving model to best_model.keras
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.1314 - val_accuracy: 0.9692
# Epoch 19/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0657 - accuracy: 0.9791
# Epoch 19: val_accuracy did not improve from 0.96924
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0660 - accuracy: 0.9790 - val_loss: 0.2129 - val_accuracy: 0.9330
# Epoch 20/20
# 234/235 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9901
# Epoch 20: val_accuracy improved from 0.96924 to 0.97417, saving model to best_model.keras
# 235/235 [==============================] - 18s 76ms/step - loss: 0.0298 - accuracy: 0.9901 - val_loss: 0.1206 - val_accuracy: 0.9742
# Saved 'final_model.h5'

# %%
model.save('final_model.h5')
np.save('mean.npy', mean)
np.save('std.npy', std)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Madhusudan\PELIXA_jupyter_Code

# %%
model.save('C:\\Users\\Madhusudan\\PELIXA_jupyter_Code\\final_model.h5')
np.save('C:\\Users\\Madhusudan\\PELIXA_jupyter_Code\\mean.npy', mean)
np.save('C:\\Users\\Madhusudan\\PELIXA_jupyter_Code\\std.npy', std)
